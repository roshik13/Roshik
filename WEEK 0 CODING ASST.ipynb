# %%
'''Comparison of weekly and monthly sales
 Create a new column
* named 'revenue' where each element is product of checkout_price and num_orders 
** named 'month' by using ['week'] column (week column value divided by 4 gives month value)'''


import pandas as pd
from matplotlib import pyplot as plt
mi = pd.read_csv("/Users/meal_info.csv")
m=pd.read_csv("/Users/train.csv")
mi = pd.merge(mi,m,on='meal_id')
plt.xlabel("Food Item")
plt.plot(range(0,5))
plt.ylabel("Quantity of food")
plt.title("Most Popular Food")
scale_factor = 10**7
ymin, ymax = plt.ylim()
plt.ylim(ymin * scale_factor, ymax * scale_factor)
plt.bar(mi['category'].unique(),mi.groupby(mi['category'])['num_orders'].sum())
plt.xticks(rotation=70)
plt.show()
'''**************************Your code******************************'''



'''******************************************************************'''
'''Here we have created two list month and month_order ,
store month number in month list and revenue of each month in month_order'''
#list to store month-wise revenue 
plt.xlabel("Week")
plt.plot(range(0,4))
plt.ylabel("Revenue")
plt.title("Weekly Income")
scale_factor = 10**8
ymin, ymax = plt.ylim()
plt.ylim(ymin * scale_factor, ymax * scale_factor)
mi['revenue']=mi['num_orders']*mi['checkout_price']
plt.plot(mi['week'].unique(),mi.groupby(mi['week'])['revenue'].sum())
plt.show()
'''***********************************Your code***********************'''

    
'''*********************************************************************'''
'''Here we have created two list week and week_order ,you need to store in them mapping the monthly orders'''    
#list to store week-wise revenue 

plt.xlabel("Month")
plt.plot(range(0,4))
plt.ylabel("Revenue")
plt.title("Monthly Income")
scale_factor = 10**9
ymin, ymax = plt.ylim()
plt.ylim(ymin * scale_factor, ymax * scale_factor)
mi['revenue']=mi['num_orders']*mi['checkout_price']
mi['month']=mi['week']
for item in mi['month']:
int(item)
mi['month']=(mi['month']%52)/4
plt.plot(mi['week'].unique(),mi.groupby(mi['month'])['revenue'].sum())
plt.show()
'''***********************************Your code***********************'''


'''*********************************************************************'''
''' Plot two subplots in the same space : one for weekly revenue and other for monthly revenue.
For weekly : Title(Weekly income),x_label(week),y_label(revenue); similarly for monthly revenue.
'''

'''************Yourcode*********************'''



''' Display the plot'''
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-77ce1ce3cd45> in <module>
#      38 ymin, ymax = plt.ylim()
#      39 plt.ylim(ymin * scale_factor, ymax * scale_factor)
# ---> 40 mi['revenue']=mi.groupby(mi['week'])[mi['num_orders']*mi['checkout_price']].sum()
#      41 plt.plot(mi['week'].unique(),mi.groupby(mi['week'])['checkout_price'].sum())
#      42 plt.show()
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1611                 stacklevel=2,
#    1612             )
# -> 1613         return super().__getitem__(key)
#    1614
#    1615     def _gotitem(self, key, ndim: int, subset=None):
#
# D:\Anaconda\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     227             if len(self.obj.columns.intersection(key)) != len(key):
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
mi = pd.read_csv("meal_info.csv")
m=pd.read_csv("train.csv")
mi = pd.merge(mi,m,on='meal_id')
mi.plot(kind='bar',x='category',y='num_orders')
#mi.plot(kind='bar' , x='category' , y='num_orders' )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f4666177ec04> in <module>
#       1 import pandas as pd
#       2 from matplotlib import pyplot as plt
# ----> 3 mi = pd.read_csv("meal_info.csv")
#       4 m=pd.read_csv("train.csv")
#       5 mi = pd.merge(mi,m,on='meal_id')
#
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
mi = pd.read_csv("/Users/meal_info.csv")
m=pd.read_csv("/Users/train.csv")
mi = pd.merge(mi,m,on='meal_id')
plt.xlabel("Food Item")
plt.plot(range(0,5))
plt.ylabel("Quantity of food")
plt.title("Most Popular Food")
scale_factor = 10**7
ymin, ymax = plt.ylim()
plt.ylim(ymin * scale_factor, ymax * scale_factor)
plt.bar(mi['category'].unique(),mi.groupby(mi['category'])['num_orders'].sum())
plt.xticks(rotation=70)
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt
mi = pd.read_csv("/Users/meal_info.csv")
mi.plot(kind='bar' ,x='category',y='meal_id')

# %%
import pandas as pd
from matplotlib import pyplot as plt
mi = pd.read_csv("/Users/meal_info.csv")
m=pd.read_csv("/Users/train.csv")
mi = pd.merge(mi,m,on='meal_id')
plt.xlabel("Month")
plt.plot(range(0,4))
plt.ylabel("Revenue")
plt.title("Monthly Income")
scale_factor = 10**9
ymin, ymax = plt.ylim()
plt.ylim(ymin * scale_factor, ymax * scale_factor)
mi['revenue']=mi['num_orders']*mi['checkout_price']
mi['month']=mi['week']
for item in mi['month']:
int(item)
mi['month']=(mi['month']%52)/4
plt.plot(mi['week'].unique(),mi.groupby(mi['month'])['revenue'].sum())
plt.show()
# Out:
#   File "<ipython-input-6-312ec969ce75>", line 16
#     int(item)
#       ^
# IndentationError: expected an indented block
